# %% [markdown]
# # Day 6 — Model Evaluation
#
# Accuracy · Precision · Recall · F1 · Confusion matrix · AI Performance Analyzer

# %%
import sys
from pathlib import Path

REPO = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(REPO / "datasets" / "scripts"))

from evaluate_models import evaluate_models

result = evaluate_models()

# %%
from IPython.display import Image, Markdown, display

eval_dir = REPO / "ml-models" / "evaluation"
display(Markdown((eval_dir / "ai_performance_analyzer.md").read_text()))
display(Image(filename=str(eval_dir / "confusion_matrix_random_forest.png")))
display(Image(filename=str(eval_dir / "feature_importance_random_forest.png")))
